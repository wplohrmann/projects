# %%
import sqlite3
import pandas as pd

# %%
sqlite_file = r'/home/william/Documents/Python/Databases/PVt_DB.sqlite'
df = pd.read_csv(r'/home/william/Dropbox/Materials Internship/Data/PZT_data/PZT_670_0Kh.txt', 
                 skiprows=49,skipfooter=14,
                 delimiter='\t')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.

# %%
conn = sqlite3.connect(sqlite_file)

df.to_sql('PVt_data',conn)


conn.close()
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py:1165: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
conn.close()

# %%
import sqlalchemy

# %%
url = r'https://en.wikipedia.org/wiki/List_of_African_countries_by_Human_Development_Index'
dfs = pd.read_html(url)

# %%
dfs[0].transpose()
# Out:
#                                                     0        1   \
# 0    Rank Country HDI Rank in Africa Rank Worldwide...     Rank
# 1                                                 Rank  Country
# 2                                              Country      HDI
# 3                                                  HDI      NaN
# 4                                       Rank in Africa      NaN
# 5                                       Rank Worldwide      NaN
# 6                          New 2015 Estimates for 2014      NaN
# 7    Change compared between 2014 report and 2013 r...      NaN
# 8                               High human development      NaN
# 9                                                    1      NaN
# 10                                                  63      NaN
# 11                                           Mauritius      NaN
# 12                                               0.777      NaN
# 13                                               0.002      NaN
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im_array = plt.imread(r'/home/william/Downloads/multipage_tif_example.tif')

# %%
plt.imshow(im_array)
plt.show()

# %%
im_array.shape
# Out:
# (44, 330, 4)

# %%
from PIL import Image

# %%
im = Image.open(r'/home/william/Downloads/a_image.tif')

# %%
im.show()

# %%
im_array = np.array(im)

# %%
im_array.shape
# Out:
# (44, 330)

# %%
Image.fromarray(im_array)
# Out:
# <PIL.Image.Image image mode=RGBA size=330x44 at 0x7F11A005A908>
